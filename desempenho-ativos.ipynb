# %% [raw]
# ---
# title: "desempenho-ativos"
# format: pptx
# editor: visual
# ---

# %% [markdown]
# ```{css, echo=FALSE}
# .bg-slide {
#   background-image: url('caminho/para/sua/imagem.jpg');
#   background-size: cover;
#   height: 100%;
#   color: white;
#   text-align: center;
#   display: flex;
#   justify-content: center;
#   align-items: center;
# }
# <div class="bg-slide">
#   <div>
#     <h1>CAPRI Family Office</h1>
#     <h2>Auxílio Reunião Semanal de Gestão</h2>
#     <p>Maio/2024</p>
#   </div>
# </div>
# ```
